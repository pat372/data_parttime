# %% [markdown]
# # Parsing APIs Example

# %% [markdown]
# ## Intro
#
# Now we will take a look on a real data. When you parse data from web you will often meet API based web-pages.
#
# For example [zalando.fr](https://www.zalando.fr/accueil-homme/) is API based web-page.
#
# In this guided lab you will learn how to obtain the links from webpages and extract the data. Read through this doc, execute the cells in order and make sure you understand the explanations.
#
# *Note: This guided lab uses Google Chrome. Other browsers like Safari and Firefox have similar tools for developers but they work differently. To save your time in following this lab, it is strongly recommended that you install and use Google Chrome.*

# %% [markdown]
# ## Obtaining the link
#
# Zalando is discount e-store where you can buy clothes and accesories with discount. When we go to the web-page, we can choose different sections. First the general process will be shown using [Children section](https://www.zalando.fr/accueil-enfant/) as example.
#
# Here we will parse data about promotions only. Therefore, final output will be the DataFrame with all the goods under discount.
#
# [![Image from Gyazo](https://i.gyazo.com/fa4874d8e81c7570273bbfb853d66308.png)](https://gyazo.com/fa4874d8e81c7570273bbfb853d66308)
#
#
# We go to Promos page. Right click of mouse shows us a list of actions possible, from which we select Inspect.
#
# <img src='https://i.gyazo.com/bccbd11d69c9040dc98758d443e32052.png' width="400">
#
#
# You will see the menu dropdown on the right side or on the bottom of the window. There you should click on Network:
#
#
# [![Image from Gyazo](https://i.gyazo.com/f7e0db81cbfee67694183d1a7640bf81.png)](https://gyazo.com/f7e0db81cbfee67694183d1a7640bf81)

# %% [markdown]
# Right after the developer part will change showing the files behind the page. In order to obtain only useful files we select the following settings:
# 1. Preserve Log
# 2. Select XHR files.
#
# [![Image from Gyazo](https://i.gyazo.com/9a899d4441d9d93e795f79747f1e47d5.png)](https://gyazo.com/9a899d4441d9d93e795f79747f1e47d5)
#
# In order to obtain some files we need to scrool down and go forward to second page.
#
# [![Image from Gyazo](https://i.gyazo.com/0956eb3d5125075a236c9a439c7749c7.png)](https://gyazo.com/0956eb3d5125075a236c9a439c7749c7)
#
# In the Network panel you can see the following files being uploaded. All the data on the web-page is uploaded from the json file, which is one of the following. It is important to understand which file contains what kind of information.
#
# <a href="https://gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c"><img src="https://i.gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c.png" alt="Image from Gyazo" width="724.8"/></a>
#
# When you find what kind of information you need for the data to be uploaded you just test it. Here we need the article... file:
#
# <a href="https://gyazo.com/78b35bf492994b3f35c0564a21da202a"><img src="https://i.gyazo.com/78b35bf492994b3f35c0564a21da202a.png" alt="Image from Gyazo" width="727.2"/></a>
#
# When we test the link in Chrome inkognito mode we obtain the proper json file:
#
#
# <a href="https://gyazo.com/b60453fa98454fa29771c731a5174443"><img src="https://i.gyazo.com/b60453fa98454fa29771c731a5174443.png" alt="Image from Gyazo" width="1530.4"/></a>

# %% [markdown]
# In order to change the objects in the json file (kind of pagination), you need to change the offset (the number of the first element on the page). in fact, if you take a look on the link, it is easy to unerstand the structure of the link.
#
# # Reading the data
#
# Now the party rocks! When we know how can we obtain the data, it is not a problem to obtain the whole database with all the data from the web-page.
# In this lab you will collect your database of Zalando products. You select which goods you want to track. You can define as many filters to your data as you want. Just make sure that the data represents the filters.

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
# Paste the url you obtained for your data
url='https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=84&sort=sale'

# %% [markdown]
# #### Collect first 84 object of the of the data (1st page)
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having *family_articles, flags, media* and *sizes* remaining lists (they are exceptions).

# %%
# Your code

response = requests.get(url, headers ={"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36"})
results = response.json()
results


flattened_data = json_normalize(results)

flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
# /Users/work/.local/share/virtualenvs/ironhack-UuIfidyp/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#
# /Users/work/.local/share/virtualenvs/ironhack-UuIfidyp/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   # Remove the CWD from sys.path while we load stuff.
#               sku                                               name  \
# 0   NI123K00V-Q11  G NSW HERITAGE FZ - Veste de survêtement - bla...
# 1   AD543D18H-K11                     T-shirt imprimé - shablu/black
# 2   SO224G0QN-K11                             T-shirt imprimé - blue
# 3   JAN24A001-Q11    JJILIAM JJORIGINAL - Jeans Skinny - black denim
# 4   AD543A281-Q11  RAPIDALUX - Chaussures de running neutres - co...
# ..            ...                                                ...
# 79  NI123F00J-G11  AIR DRESS - Robe en jersey - washed coral/trac...
# 80  GS123A00E-K11                                Jeans Skinny - blue
# 81  NA823K0JR-K11         NKFBERNADETTE - Sweatshirt - dark sapphire
# 82  NI153I005-J11                   Sac à dos - magic flamingo/white
# 83  SO224G0Q4-E11  LANGARM - T-shirt à manches longues - golden y...
#
#                                                 sizes  \
# 0                               [10-11a, 12-13a, 14a]
# 1               [7-8a, 9-10a, 11-12a, 13-14a, 15-16a]
# 2                      [4-5axREG, 6-7axREG, 8-9axREG]
# 3         [8a, 9a, 10a, 11a, 12a, 13a, 14a, 15a, 16a]
# 4   [35.5, 36, 38, 40, 36 2/3, 37 1/3, 38 2/3, 39 ...
# ..                                                ...
# 79                        [8-9a, 10-11a, 12-13a, 14a]
# 80                        [4a, 5a, 6a, 12a, 14a, 16a]
# 81                  [6a, 7-8a, 9-10a, 11-12a, 13-14a]
# 82                                         [One Size]
# 83                     [4-5axREG, 6-7axREG, 8-9axREG]
#
#                                               url_key  \
# 0   nike-sportswear-heritage-veste-de-survetement-...
# 1   adidas-performance-t-shirt-de-sport-shablublac...
# 2          soliver-t-shirt-imprime-blue-so224g0qn-k11
# 3   jackandjones-junior-jjiliam-jjoriginal-jeans-s...
# 4   adidas-performance-rapidalux-chaussures-de-run...
# ..                                                ...
# 79  nike-sportswear-air-dress-robe-en-jersey-washe...
# 80             g-star-jeans-skinny-blue-gs123a00e-k11
# 81  name-it-nkfbernadette-sweatshirt-dark-sapphire...
# 82  nike-sportswear-sac-a-dos-magic-flamingowhite-...
# 83  soliver-langarm-t-shirt-a-manches-longues-gold...
#
#                                                 media           brand_name  \
# 0   [{'path': 'NI/12/3K/00/VQ/11/NI123K00V-Q11@8.j...      Nike Sportswear
# 1   [{'path': 'AD/54/3D/18/HK/11/AD543D18H-K11@6.j...   adidas Performance
# 2   [{'path': 'SO/22/4G/0Q/NK/11/SO224G0QN-K11@7.j...             s.Oliver
# 3   [{'path': 'JA/N2/4A/00/1Q/11/JAN24A001-Q11@7.j...  Jack & Jones Junior
# 4   [{'path': 'AD/54/3A/28/1Q/11/AD543A281-Q11@9.j...   adidas Performance
# ..                                                ...                  ...
# 79  [{'path': 'NI/12/3F/00/JG/11/NI123F00J-G11@5.j...      Nike Sportswear
# 80  [{'path': 'GS/12/3A/00/EK/11/GS123A00E-K11@2.j...               G-Star
# 81  [{'path': 'NA/82/3K/0J/RK/11/NA823K0JR-K11@5.j...              Name it
# 82  [{'path': 'NI/15/3I/00/5J/11/NI153I005-J11@9.j...      Nike Sportswear
# 83  [{'path': 'SO/22/4G/0Q/4E/11/SO224G0Q4-E11@8.j...             s.Oliver
#
#     is_premium                                    family_articles  \
# 0        False  [{'sku': 'NI123K00V-Q11', 'url_key': 'nike-spo...
# 1        False  [{'sku': 'AD543D18H-K11', 'url_key': 'adidas-p...
# 2        False  [{'sku': 'SO224G0QN-K11', 'url_key': 'soliver-...
# 3        False  [{'sku': 'JAN24A001-Q11', 'url_key': 'jackandj...
# 4        False  [{'sku': 'AD543A281-Q11', 'url_key': 'adidas-p...
# ..         ...                                                ...
# 79       False  [{'sku': 'NI123F00J-G11', 'url_key': 'nike-spo...
# 80       False  [{'sku': 'GS123A00E-K11', 'url_key': 'g-star-j...
# 81       False  [{'sku': 'NA823K0JR-K11', 'url_key': 'name-it-...
# 82       False  [{'sku': 'NI153I005-J11', 'url_key': 'nike-spo...
# 83       False  [{'sku': 'SO224G0Q4-E11', 'url_key': 'soliver-...
#
#                                                 flags product_group  \
# 0   [{'key': 'campaign', 'value': '-15% EXTRA', 't...      clothing
# 1   [{'key': 'campaign', 'value': '-15% EXTRA', 't...      clothing
# 2   [{'key': 'campaign', 'value': '-15% EXTRA', 't...      clothing
# 3   [{'key': 'campaign', 'value': '-15% EXTRA', 't...      clothing
# 4   [{'key': 'campaign', 'value': '-15% EXTRA', 't...          shoe
# ..                                                ...           ...
# 79  [{'key': 'campaign', 'value': '-15% EXTRA', 't...      clothing
# 80  [{'key': 'campaign', 'value': '-15% EXTRA', 't...      clothing
# 81  [{'key': 'campaign', 'value': '-15% EXTRA', 't...      clothing
# 82  [{'key': 'campaign', 'value': '-15% EXTRA', 't...   accessoires
# 83  [{'key': 'campaign', 'value': '-15% EXTRA', 't...      clothing
#
#    delivery_promises price.original price.promotional  \
# 0                 []        44,95 €           17,95 €
# 1                 []        27,95 €           11,15 €
# 2                 []        14,99 €            5,59 €
# 3                 []        29,95 €           20,95 €
# 4                 []        89,95 €           35,95 €
# ..               ...            ...               ...
# 79                []        44,95 €           17,95 €
# 80                []        69,95 €           31,45 €
# 81                []        26,99 €           10,79 €
# 82                []        24,95 €           18,75 €
# 83                []        15,99 €            9,59 €
#
#     price.has_different_prices  price.has_different_original_prices  \
# 0                        False                                False
# 1                        False                                False
# 2                        False                                False
# 3                        False                                False
# 4                         True                                False
# ..                         ...                                  ...
# 79                       False                                False
# 80                       False                                False
# 81                       False                                False
# 82                       False                                False
# 83                       False                                False
#
#     price.has_different_promotional_prices  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                     True
# ..                                     ...
# 79                                   False
# 80                                   False
# 81                                   False
# 82                                   False
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only amount
# 0                                       False    NaN
# 1                                       False    NaN
# 2                                       False    NaN
# 3                                       False    NaN
# 4                                       False  208 g
# ..                                        ...    ...
# 79                                      False    NaN
# 80                                      False    NaN
# 81                                      False    NaN
# 82                                      False    NaN
# 83                                      False    NaN
#
# [84 rows x 18 columns]

# %% [markdown]
# #### Collect all the objects from selected filters. Total number of pages can be found in the same json. Use *sku* column as index.
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having family_articles, flags, media and sizes remaining lists (they are exceptions).

# %%
# Get the total number of pages
total_pages=results['pagination']['page_count']

# Your code
df=pd.DataFrame()
for i in range(total_pages):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset={k}&sort=sale'
    response = requests.get(url, headers ={"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36"})
    results = response.json()
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)
    break

df
# Out:
# /Users/work/.local/share/virtualenvs/ironhack-UuIfidyp/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   # This is added back by InteractiveShellApp.init_path()
# /Users/work/.local/share/virtualenvs/ironhack-UuIfidyp/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   if sys.path[0] == '':
#                                                             name  \
# sku
# LE213D004-K11             SPRINGFIELD - Mocassins - navy/red/blu
# AD116D0QW-I11  SUPERSTAR  - Baskets basses - purple tint/lege...
# HA113G002-F11                           LUNA - Tongs - rose gold
# NI113D09V-A11  AIR MAX 270 EXTREME - Mocassins - white/ghost ...
# AD123K01P-K11        TREFOIL CREW - Sweatshirt - dark blue/white
# ...                                                          ...
# NI114D0DI-K13  RENEW 55 - Baskets basses - hyper blue/white/g...
# NI114D0C1-G11  AIR MAX TAILWIND IV - Baskets basses - univers...
# SO224G0Q2-C11             T-shirt à manches longues - light grey
# NI113D0AG-A11           BLAZER POP - Baskets basses - white/volt
# SO223G0SG-K11              T-shirt à manches longues - dark blue
#
#                                                            sizes  \
# sku
# LE213D004-K11                       [29, 30, 31, 32, 33, 34, 35]
# AD116D0QW-I11                                   [20, 22, 25, 26]
# HA113G002-F11                              [27/28, 29/30, 31/32]
# NI113D09V-A11  [27.5, 28, 28.5, 29.5, 30, 31, 31.5, 32, 33.5,...
# AD123K01P-K11      [8-9a, 9-10a, 10-11a, 11-12a, 12-13a, 13-14a]
# ...                                                          ...
# NI114D0DI-K13                       [36, 37.5, 38, 38.5, 39, 40]
# NI114D0C1-G11                         [36.5, 37.5, 38, 38.5, 39]
# SO224G0Q2-C11                                         [8-9axREG]
# NI113D0AG-A11                   [35.5, 36, 36.5, 37.5, 38, 38.5]
# SO223G0SG-K11                     [4-5axREG, 6-7axREG, 8-9axREG]
#
#                                                          url_key  \
# sku
# LE213D004-K11     levisr-baskets-basses-navyredblu-le213d004-k11
# AD116D0QW-I11  adidas-originals-superstar-baskets-basses-purp...
# HA113G002-F11            havaianas-kids-luna-tongs-ha113g002-f11
# NI113D09V-A11  nike-sportswear-air-max-270-extreme-baskets-ba...
# AD123K01P-K11  adidas-originals-trefoil-crew-sweatshirt-ad123...
# ...                                                          ...
# NI114D0DI-K13  nike-sportswear-renew-element-55-baskets-basse...
# NI114D0C1-G11  nike-sportswear-air-max-tailwind-baskets-basse...
# SO224G0Q2-C11  soliver-t-shirt-a-manches-longues-light-grey-s...
# NI113D0AG-A11  nike-sportswear-blazer-pop-baskets-basses-whit...
# SO223G0SG-K11  soliver-t-shirt-a-manches-longues-dark-blue-so...
#
#                                                            media  \
# sku
# LE213D004-K11  [{'path': 'LE/21/3D/00/4K/11/LE213D004-K11@8.1...
# AD116D0QW-I11  [{'path': 'AD/11/6D/0Q/WI/11/AD116D0QW-I11@9.j...
# HA113G002-F11  [{'path': 'HA/11/3G/00/2F/11/HA113G002-F11@11....
# NI113D09V-A11  [{'path': 'NI/11/3D/09/VA/11/NI113D09V-A11@7.j...
# AD123K01P-K11  [{'path': 'AD/12/3K/01/PK/11/AD123K01P-K11@21....
# ...                                                          ...
# NI114D0DI-K13  [{'path': 'NI/11/4D/0D/IK/13/NI114D0DI-K13@7.j...
# NI114D0C1-G11  [{'path': 'NI/11/4D/0C/1G/11/NI114D0C1-G11@6.j...
# SO224G0Q2-C11  [{'path': 'SO/22/4G/0Q/2C/11/SO224G0Q2-C11@6.j...
# NI113D0AG-A11  [{'path': 'NI/11/3D/0A/GA/11/NI113D0AG-A11@26....
# SO223G0SG-K11  [{'path': 'SO/22/3G/0S/GK/11/SO223G0SG-K11@7.j...
#
#                      brand_name  is_premium  \
# sku
# LE213D004-K11           Levi's®       False
# AD116D0QW-I11  adidas Originals       False
# HA113G002-F11         Havaianas       False
# NI113D09V-A11   Nike Sportswear       False
# AD123K01P-K11  adidas Originals       False
# ...                         ...         ...
# NI114D0DI-K13   Nike Sportswear       False
# NI114D0C1-G11   Nike Sportswear       False
# SO224G0Q2-C11          s.Oliver       False
# NI113D0AG-A11   Nike Sportswear       False
# SO223G0SG-K11          s.Oliver       False
#
#                                                  family_articles  \
# sku
# LE213D004-K11  [{'sku': 'LE213D004-K11', 'url_key': 'levisr-b...
# AD116D0QW-I11  [{'sku': 'AD116D0QW-I11', 'url_key': 'adidas-o...
# HA113G002-F11  [{'sku': 'HA113G002-F11', 'url_key': 'havaiana...
# NI113D09V-A11  [{'sku': 'NI113D09V-A11', 'url_key': 'nike-spo...
# AD123K01P-K11  [{'sku': 'AD123K01P-K11', 'url_key': 'adidas-o...
# ...                                                          ...
# NI114D0DI-K13  [{'sku': 'NI114D0DI-K13', 'url_key': 'nike-spo...
# NI114D0C1-G11  [{'sku': 'NI114D0C1-G11', 'url_key': 'nike-spo...
# SO224G0Q2-C11  [{'sku': 'SO224G0Q2-C11', 'url_key': 'soliver-...
# NI113D0AG-A11  [{'sku': 'NI113D0AG-A11', 'url_key': 'nike-spo...
# SO223G0SG-K11  [{'sku': 'SO223G0SG-K11', 'url_key': 'soliver-...
#
#                                                            flags  \
# sku
# LE213D004-K11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# AD116D0QW-I11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# HA113G002-F11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# NI113D09V-A11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# AD123K01P-K11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# ...                                                          ...
# NI114D0DI-K13  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# NI114D0C1-G11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# SO224G0Q2-C11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# NI113D0AG-A11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# SO223G0SG-K11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
#
#               product_group delivery_promises price.original  \
# sku
# LE213D004-K11          shoe                []        44,95 €
# AD116D0QW-I11          shoe                []        54,95 €
# HA113G002-F11          shoe                []        19,95 €
# NI113D09V-A11          shoe                []        89,95 €
# AD123K01P-K11      clothing                []        37,95 €
# ...                     ...               ...            ...
# NI114D0DI-K13          shoe                []        74,95 €
# NI114D0C1-G11          shoe                []       139,95 €
# SO224G0Q2-C11      clothing                []        15,99 €
# NI113D0AG-A11          shoe                []        69,95 €
# SO223G0SG-K11      clothing                []        15,99 €
#
#               price.promotional  price.has_different_prices  \
# sku
# LE213D004-K11           26,95 €                        True
# AD116D0QW-I11           41,45 €                       False
# HA113G002-F11           17,95 €                       False
# NI113D09V-A11           35,95 €                       False
# AD123K01P-K11           15,15 €                        True
# ...                         ...                         ...
# NI114D0DI-K13           29,95 €                       False
# NI114D0C1-G11           62,95 €                       False
# SO224G0Q2-C11            6,39 €                       False
# NI113D0AG-A11           27,95 €                       False
# SO223G0SG-K11            6,39 €                       False
#
#                price.has_different_original_prices  \
# sku
# LE213D004-K11                                False
# AD116D0QW-I11                                False
# HA113G002-F11                                False
# NI113D09V-A11                                False
# AD123K01P-K11                                False
# ...                                            ...
# NI114D0DI-K13                                False
# NI114D0C1-G11                                False
# SO224G0Q2-C11                                False
# NI113D0AG-A11                                False
# SO223G0SG-K11                                False
#
#                price.has_different_promotional_prices  \
# sku
# LE213D004-K11                                    True
# AD116D0QW-I11                                   False
# HA113G002-F11                                   False
# NI113D09V-A11                                   False
# AD123K01P-K11                                    True
# ...                                               ...
# NI114D0DI-K13                                   False
# NI114D0C1-G11                                   False
# SO224G0Q2-C11                                   False
# NI113D0AG-A11                                   False
# SO223G0SG-K11                                   False
#
#                price.has_discount_on_selected_sizes_only  \
# sku
# LE213D004-K11                                      False
# AD116D0QW-I11                                      False
# HA113G002-F11                                      False
# NI113D09V-A11                                      False
# AD123K01P-K11                                      False
# ...                                                  ...
# NI114D0DI-K13                                      False
# NI114D0C1-G11                                      False
# SO224G0Q2-C11                                      False
# NI113D0AG-A11                                      False
# SO223G0SG-K11                                      False
#
#                     tracking_information.metrigo_impression_urls  \
# sku
# LE213D004-K11  [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# AD116D0QW-I11  [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# HA113G002-F11  [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# NI113D09V-A11                                                NaN
# AD123K01P-K11                                                NaN
# ...                                                          ...
# NI114D0DI-K13                                                NaN
# NI114D0C1-G11                                                NaN
# SO224G0Q2-C11                                                NaN
# NI113D0AG-A11                                                NaN
# SO223G0SG-K11                                                NaN
#
#                           tracking_information.impression_beacon  \
# sku
# LE213D004-K11  https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# AD116D0QW-I11  https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# HA113G002-F11  https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# NI113D09V-A11                                                NaN
# AD123K01P-K11                                                NaN
# ...                                                          ...
# NI114D0DI-K13                                                NaN
# NI114D0C1-G11                                                NaN
# SO224G0Q2-C11                                                NaN
# NI113D0AG-A11                                                NaN
# SO223G0SG-K11                                                NaN
#
#               tracking_information.source
# sku
# LE213D004-K11                         ccp
# AD116D0QW-I11                         ccp
# HA113G002-F11                         ccp
# NI113D09V-A11                         NaN
# AD123K01P-K11                         NaN
# ...                                   ...
# NI114D0DI-K13                         NaN
# NI114D0C1-G11                         NaN
# SO224G0Q2-C11                         NaN
# NI113D0AG-A11                         NaN
# SO223G0SG-K11                         NaN
#
# [84 rows x 19 columns]

# %% [markdown]
# #### Display the trending brand in DataFrame

# %%
df.brand_name.value_counts().index[0]
# Out:
# 'Nike Sportswear'

# %% [markdown]
# #### Display the brand with maximal total discount (sum of discounts on all goods)

# %%
#Our data is still text. Convert prices into numbers:
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

# %%
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

# %%
df
# Out:
#                                                             name  \
# sku
# LE213D004-K11             SPRINGFIELD - Mocassins - navy/red/blu
# AD116D0QW-I11  SUPERSTAR  - Baskets basses - purple tint/lege...
# HA113G002-F11                           LUNA - Tongs - rose gold
# NI113D09V-A11  AIR MAX 270 EXTREME - Mocassins - white/ghost ...
# AD123K01P-K11        TREFOIL CREW - Sweatshirt - dark blue/white
# ...                                                          ...
# NI114D0DI-K13  RENEW 55 - Baskets basses - hyper blue/white/g...
# NI114D0C1-G11  AIR MAX TAILWIND IV - Baskets basses - univers...
# SO224G0Q2-C11             T-shirt à manches longues - light grey
# NI113D0AG-A11           BLAZER POP - Baskets basses - white/volt
# SO223G0SG-K11              T-shirt à manches longues - dark blue
#
#                                                            sizes  \
# sku
# LE213D004-K11                       [29, 30, 31, 32, 33, 34, 35]
# AD116D0QW-I11                                   [20, 22, 25, 26]
# HA113G002-F11                              [27/28, 29/30, 31/32]
# NI113D09V-A11  [27.5, 28, 28.5, 29.5, 30, 31, 31.5, 32, 33.5,...
# AD123K01P-K11      [8-9a, 9-10a, 10-11a, 11-12a, 12-13a, 13-14a]
# ...                                                          ...
# NI114D0DI-K13                       [36, 37.5, 38, 38.5, 39, 40]
# NI114D0C1-G11                         [36.5, 37.5, 38, 38.5, 39]
# SO224G0Q2-C11                                         [8-9axREG]
# NI113D0AG-A11                   [35.5, 36, 36.5, 37.5, 38, 38.5]
# SO223G0SG-K11                     [4-5axREG, 6-7axREG, 8-9axREG]
#
#                                                          url_key  \
# sku
# LE213D004-K11     levisr-baskets-basses-navyredblu-le213d004-k11
# AD116D0QW-I11  adidas-originals-superstar-baskets-basses-purp...
# HA113G002-F11            havaianas-kids-luna-tongs-ha113g002-f11
# NI113D09V-A11  nike-sportswear-air-max-270-extreme-baskets-ba...
# AD123K01P-K11  adidas-originals-trefoil-crew-sweatshirt-ad123...
# ...                                                          ...
# NI114D0DI-K13  nike-sportswear-renew-element-55-baskets-basse...
# NI114D0C1-G11  nike-sportswear-air-max-tailwind-baskets-basse...
# SO224G0Q2-C11  soliver-t-shirt-a-manches-longues-light-grey-s...
# NI113D0AG-A11  nike-sportswear-blazer-pop-baskets-basses-whit...
# SO223G0SG-K11  soliver-t-shirt-a-manches-longues-dark-blue-so...
#
#                                                            media  \
# sku
# LE213D004-K11  [{'path': 'LE/21/3D/00/4K/11/LE213D004-K11@8.1...
# AD116D0QW-I11  [{'path': 'AD/11/6D/0Q/WI/11/AD116D0QW-I11@9.j...
# HA113G002-F11  [{'path': 'HA/11/3G/00/2F/11/HA113G002-F11@11....
# NI113D09V-A11  [{'path': 'NI/11/3D/09/VA/11/NI113D09V-A11@7.j...
# AD123K01P-K11  [{'path': 'AD/12/3K/01/PK/11/AD123K01P-K11@21....
# ...                                                          ...
# NI114D0DI-K13  [{'path': 'NI/11/4D/0D/IK/13/NI114D0DI-K13@7.j...
# NI114D0C1-G11  [{'path': 'NI/11/4D/0C/1G/11/NI114D0C1-G11@6.j...
# SO224G0Q2-C11  [{'path': 'SO/22/4G/0Q/2C/11/SO224G0Q2-C11@6.j...
# NI113D0AG-A11  [{'path': 'NI/11/3D/0A/GA/11/NI113D0AG-A11@26....
# SO223G0SG-K11  [{'path': 'SO/22/3G/0S/GK/11/SO223G0SG-K11@7.j...
#
#                      brand_name  is_premium  \
# sku
# LE213D004-K11           Levi's®       False
# AD116D0QW-I11  adidas Originals       False
# HA113G002-F11         Havaianas       False
# NI113D09V-A11   Nike Sportswear       False
# AD123K01P-K11  adidas Originals       False
# ...                         ...         ...
# NI114D0DI-K13   Nike Sportswear       False
# NI114D0C1-G11   Nike Sportswear       False
# SO224G0Q2-C11          s.Oliver       False
# NI113D0AG-A11   Nike Sportswear       False
# SO223G0SG-K11          s.Oliver       False
#
#                                                  family_articles  \
# sku
# LE213D004-K11  [{'sku': 'LE213D004-K11', 'url_key': 'levisr-b...
# AD116D0QW-I11  [{'sku': 'AD116D0QW-I11', 'url_key': 'adidas-o...
# HA113G002-F11  [{'sku': 'HA113G002-F11', 'url_key': 'havaiana...
# NI113D09V-A11  [{'sku': 'NI113D09V-A11', 'url_key': 'nike-spo...
# AD123K01P-K11  [{'sku': 'AD123K01P-K11', 'url_key': 'adidas-o...
# ...                                                          ...
# NI114D0DI-K13  [{'sku': 'NI114D0DI-K13', 'url_key': 'nike-spo...
# NI114D0C1-G11  [{'sku': 'NI114D0C1-G11', 'url_key': 'nike-spo...
# SO224G0Q2-C11  [{'sku': 'SO224G0Q2-C11', 'url_key': 'soliver-...
# NI113D0AG-A11  [{'sku': 'NI113D0AG-A11', 'url_key': 'nike-spo...
# SO223G0SG-K11  [{'sku': 'SO223G0SG-K11', 'url_key': 'soliver-...
#
#                                                            flags  \
# sku
# LE213D004-K11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# AD116D0QW-I11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# HA113G002-F11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# NI113D09V-A11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# AD123K01P-K11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# ...                                                          ...
# NI114D0DI-K13  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# NI114D0C1-G11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# SO224G0Q2-C11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# NI113D0AG-A11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# SO223G0SG-K11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
#
#               product_group delivery_promises price.original  \
# sku
# LE213D004-K11          shoe                []          44.95
# AD116D0QW-I11          shoe                []          54.95
# HA113G002-F11          shoe                []          19.95
# NI113D09V-A11          shoe                []          89.95
# AD123K01P-K11      clothing                []          37.95
# ...                     ...               ...            ...
# NI114D0DI-K13          shoe                []          74.95
# NI114D0C1-G11          shoe                []         139.95
# SO224G0Q2-C11      clothing                []          15.99
# NI113D0AG-A11          shoe                []          69.95
# SO223G0SG-K11      clothing                []          15.99
#
#               price.promotional  price.has_different_prices  \
# sku
# LE213D004-K11             26.95                        True
# AD116D0QW-I11             41.45                       False
# HA113G002-F11             17.95                       False
# NI113D09V-A11             35.95                       False
# AD123K01P-K11             15.15                        True
# ...                         ...                         ...
# NI114D0DI-K13             29.95                       False
# NI114D0C1-G11             62.95                       False
# SO224G0Q2-C11              6.39                       False
# NI113D0AG-A11             27.95                       False
# SO223G0SG-K11              6.39                       False
#
#                price.has_different_original_prices  \
# sku
# LE213D004-K11                                False
# AD116D0QW-I11                                False
# HA113G002-F11                                False
# NI113D09V-A11                                False
# AD123K01P-K11                                False
# ...                                            ...
# NI114D0DI-K13                                False
# NI114D0C1-G11                                False
# SO224G0Q2-C11                                False
# NI113D0AG-A11                                False
# SO223G0SG-K11                                False
#
#                price.has_different_promotional_prices  \
# sku
# LE213D004-K11                                    True
# AD116D0QW-I11                                   False
# HA113G002-F11                                   False
# NI113D09V-A11                                   False
# AD123K01P-K11                                    True
# ...                                               ...
# NI114D0DI-K13                                   False
# NI114D0C1-G11                                   False
# SO224G0Q2-C11                                   False
# NI113D0AG-A11                                   False
# SO223G0SG-K11                                   False
#
#                price.has_discount_on_selected_sizes_only  \
# sku
# LE213D004-K11                                      False
# AD116D0QW-I11                                      False
# HA113G002-F11                                      False
# NI113D09V-A11                                      False
# AD123K01P-K11                                      False
# ...                                                  ...
# NI114D0DI-K13                                      False
# NI114D0C1-G11                                      False
# SO224G0Q2-C11                                      False
# NI113D0AG-A11                                      False
# SO223G0SG-K11                                      False
#
#                     tracking_information.metrigo_impression_urls  \
# sku
# LE213D004-K11  [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# AD116D0QW-I11  [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# HA113G002-F11  [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# NI113D09V-A11                                                NaN
# AD123K01P-K11                                                NaN
# ...                                                          ...
# NI114D0DI-K13                                                NaN
# NI114D0C1-G11                                                NaN
# SO224G0Q2-C11                                                NaN
# NI113D0AG-A11                                                NaN
# SO223G0SG-K11                                                NaN
#
#                           tracking_information.impression_beacon  \
# sku
# LE213D004-K11  https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# AD116D0QW-I11  https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# HA113G002-F11  https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# NI113D09V-A11                                                NaN
# AD123K01P-K11                                                NaN
# ...                                                          ...
# NI114D0DI-K13                                                NaN
# NI114D0C1-G11                                                NaN
# SO224G0Q2-C11                                                NaN
# NI113D0AG-A11                                                NaN
# SO223G0SG-K11                                                NaN
#
#               tracking_information.source  discount_amount
# sku
# LE213D004-K11                         ccp             18.0
# AD116D0QW-I11                         ccp             13.5
# HA113G002-F11                         ccp              2.0
# NI113D09V-A11                         NaN             54.0
# AD123K01P-K11                         NaN             22.8
# ...                                   ...              ...
# NI114D0DI-K13                         NaN             45.0
# NI114D0C1-G11                         NaN             77.0
# SO224G0Q2-C11                         NaN              9.6
# NI113D0AG-A11                         NaN             42.0
# SO223G0SG-K11                         NaN              9.6
#
# [84 rows x 20 columns]

# %%
total_disc=df1.groupby(['brand_name']).sum().discount_amount

# %%
total_disc.sort_values(ascending=False).index[0]
# Out:
# 'Nike Sportswear'

# %% [markdown]
# #### Display the brands without discount at all

# %%
total_disc[total_disc==0]
# Out:
# Series([], Name: discount_amount, dtype: float64)

# %%
total_disc
# Out:
# brand_name
# Abercrombie & Fitch      20.30
# Calvin Klein Jeans       19.30
# Cars Jeans               42.00
# Champion                 25.40
# Converse                 47.00
# Dr. Martens              49.50
# Fila                    167.50
# GAP                      19.10
# Guess                    72.00
# Havaianas                 4.00
# Kaporal                  17.30
# Levi's®                 194.90
# Name it                  13.20
# Napapijri                87.50
# Nike SB                  30.00
# Nike Sportswear        1181.30
# OVS                      18.00
# Polo Ralph Lauren         2.80
# Puma                     18.00
# Quiksilver                6.40
# Redskins                 28.70
# River Island             10.75
# Superfit                 56.30
# Tommy Hilfiger            6.00
# Vans                     12.50
# WE Fashion               13.99
# Woden                    66.50
# adidas Originals        136.35
# s.Oliver                 19.20
# Name: discount_amount, dtype: float64
