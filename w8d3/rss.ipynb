# %%
import feedparser
from pprint import pprint

# %%
lemonde = feedparser.parse("https://www.lemonde.fr/rss/une.xml")

# %%
lemonde.entries
# Out:
# [{'title': 'Donald Trump a cent jours pour relancer sa campagne avant l’élection présidentielle',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://www.lemonde.fr/rss/une.xml',
#    'value': 'Donald Trump a cent jours pour relancer sa campagne avant l’élection présidentielle'},
#   'published': 'Sat, 25 Jul 2020 10:34:38 +0200',
#   'published_parsed': time.struct_time(tm_year=2020, tm_mon=7, tm_mday=25, tm_hour=8, tm_min=34, tm_sec=38, tm_wday=5, tm_yday=207, tm_isdst=0),
#   'summary': 'Le président américain décroche dans l’opinion, du fait de sa gestion calamiteuse de la crise sanitaire. Ses difficultés alimentent \xa0la nervosité du camp républicain.',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://www.lemonde.fr/rss/une.xml',
# ...

# %%
for entry in lemonde.entries:
    pprint(entry)
# Out:
# {'credit': 'Patrick Semansky / AP',
#  'guidislink': True,
#  'id': 'https://www.lemonde.fr/international/article/2020/07/25/donald-trump-a-cent-jours-pour-relancer-sa-campagne-avant-l-election-presidentielle_6047265_3210.html',
#  'link': 'https://www.lemonde.fr/international/article/2020/07/25/donald-trump-a-cent-jours-pour-relancer-sa-campagne-avant-l-election-presidentielle_6047265_3210.html',
#  'links': [{'href': 'https://www.lemonde.fr/international/article/2020/07/25/donald-trump-a-cent-jours-pour-relancer-sa-campagne-avant-l-election-presidentielle_6047265_3210.html',
#             'rel': 'alternate',
#             'type': 'text/html'}],
#  'media_content': [{'height': '322',
#                     'url': 'https://img.lemde.fr/2020/07/25/575/0/4277/2134/644/322/60/0/f1bcbd9_8ac000f451cd44d3a071737b051b2020-8ac000f451cd44d3a071737b051b2020-0.jpg',
#                     'width': '644'}],
#  'media_credit': [{'content': 'Patrick Semansky / AP', 'scheme': 'urn:ebu'}],
# ...

# %%
import pandas as pd

# %%
pd.DataFrame(lemonde.entries)
# Out:
#                                                 title  \
# 0   Donald Trump a cent jours pour relancer sa cam...
# 1   Jean Castex annonce que la forfaitisation des ...
# 2   En visite dans un Liban en crise, Jean-Yves Le...
# 3   Piotr Verzilov ou l’art de survivre en Russie ...
# 4   Coronavirus en France : pompiers et aides-soig...
# 5   Qui est Bari Weiss, la journaliste qui vient d...
# 6   Charles Michel : « Ce qui est sur la table, c’...
# 7   Le Paris-Saint-Germain gagne la Coupe de Franc...
# 8   Coronavirus : les hôpitaux franciliens sur le ...
# 9   Coronavirus : les restrictions se multiplient ...
# 10  Avec le confinement, la prématurité a chuté da...
# 11  L’extradition du Chili de Nicolas Zepeda, « pa...
# 12  Patrick Balkany mis en examen pour « détournem...
# 13  Futur vaccin contre le Covid-19 : de premières...
# 14  Solocal : les actionnaires valident le plan de...
# 15  La gazette virtuelle des JO : Alaphilippe vict...
# ...
