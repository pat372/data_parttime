# %%
# pandas compared to numpy : tabular data
# data structure : series and dataframe
# build from various sources : csv, sql, etc.
# dtore to various sources : csv, sql, etc.
# build dataframe out of other python data structures : numpy array, list, dict
# transpose
# math operations on columns

# %%
import pandas as pd

# %%
#pandas
#tabular data
#excel, csv, table sql, etc.
#données structurées
#séries temporelles ordonnées par temps croissant
#données matricielles numériques (numpy)

# %%
#Series (1-dimensional)
#Dataframe (2-dimensional)

# %%
#gérer les valeurs manquantes
#suppression de colonnes, insertions de colonnes
#pouvoir créer à partir de formats différents des dataframes
#slicing, fancy indexing, etc.
#fusionner, faire des jointures entre dataframes
#ensembles d'outils pour les séries temporelles

# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
df = pd.DataFrame(np.random.randn(6, 4))

# %%
df
# Out:
#           0         1         2         3
# 0  0.824288 -1.168105 -0.825635 -0.513322
# 1 -1.498789 -0.637447 -0.742365 -1.022618
# 2  1.055932  1.956623  1.104500 -0.685065
# 3 -0.964952  1.267604 -0.190442 -0.705002
# 4  1.982324  0.225725  0.216965  0.528426
# 5 -0.170905 -0.396436 -0.712652  0.404153

# %%
dates = pd.date_range('20200101', periods=6)
dates
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=['A', 'B', 'C', 'D'])

# %%
df
# Out:
#                    A         B         C         D
# 2020-01-01 -2.143367 -0.770190  1.032366  0.513735
# 2020-01-02  0.146340  1.476347  0.500801  0.964730
# 2020-01-03 -0.187262  1.055270  1.896475  0.167401
# 2020-01-04  0.015641  0.580618 -1.255689 -2.031519
# 2020-01-05  0.403747  0.330787 -0.763140 -0.266199
# 2020-01-06 -0.767717  0.959169 -0.041342 -0.463239

# %%
df2 = pd.DataFrame({
                    'A': 1.,
                    'B': pd.Timestamp('20200704'),
                    'C': pd.Series(1, index=list(range(4)), dtype='float32'),
                    'D': np.array([3] * 4, dtype='int32'),
                    'E': 'foo'
})

# %%
df2
# Out:
#      A          B    C  D    E
# 0  1.0 2020-07-04  1.0  3  foo
# 1  1.0 2020-07-04  1.0  3  foo
# 2  1.0 2020-07-04  1.0  3  foo
# 3  1.0 2020-07-04  1.0  3  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E            object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2020-01-01 -2.143367 -0.770190  1.032366  0.513735
# 2020-01-02  0.146340  1.476347  0.500801  0.964730
# 2020-01-03 -0.187262  1.055270  1.896475  0.167401
# 2020-01-04  0.015641  0.580618 -1.255689 -2.031519
# 2020-01-05  0.403747  0.330787 -0.763140 -0.266199

# %%
df.tail(2)
# Out:
#                    A         B         C         D
# 2020-01-05  0.403747  0.330787 -0.763140 -0.266199
# 2020-01-06 -0.767717  0.959169 -0.041342 -0.463239

# %%
df.index
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[-2.14336726, -0.77018987,  1.03236648,  0.51373501],
#        [ 0.14633985,  1.47634691,  0.50080055,  0.96473011],
#        [-0.18726152,  1.05526989,  1.89647506,  0.16740145],
#        [ 0.01564086,  0.58061752, -1.2556886 , -2.03151879],
#        [ 0.40374713,  0.33078711, -0.76313969, -0.2661989 ],
#        [-0.7677174 ,  0.95916928, -0.04134234, -0.46323893]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.422103  0.605333  0.228245 -0.185848
# std    0.931034  0.781583  1.162882  1.041915
# min   -2.143367 -0.770190 -1.255689 -2.031519
# 25%   -0.622603  0.393245 -0.582690 -0.413979
# 50%   -0.085810  0.769893  0.229729 -0.049399
# 75%    0.113665  1.031245  0.899475  0.427152
# max    0.403747  1.476347  1.896475  0.964730

# %%
df.T
# Out:
#    2020-01-01  2020-01-02  2020-01-03  2020-01-04  2020-01-05  2020-01-06
# A   -2.143367    0.146340   -0.187262    0.015641    0.403747   -0.767717
# B   -0.770190    1.476347    1.055270    0.580618    0.330787    0.959169
# C    1.032366    0.500801    1.896475   -1.255689   -0.763140   -0.041342
# D    0.513735    0.964730    0.167401   -2.031519   -0.266199   -0.463239

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2020-01-01  0.513735  1.032366 -0.770190 -2.143367
# 2020-01-02  0.964730  0.500801  1.476347  0.146340
# 2020-01-03  0.167401  1.896475  1.055270 -0.187262
# 2020-01-04 -2.031519 -1.255689  0.580618  0.015641
# 2020-01-05 -0.266199 -0.763140  0.330787  0.403747
# 2020-01-06 -0.463239 -0.041342  0.959169 -0.767717

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2020-01-01 -2.143367 -0.770190  1.032366  0.513735
# 2020-01-05  0.403747  0.330787 -0.763140 -0.266199
# 2020-01-04  0.015641  0.580618 -1.255689 -2.031519
# 2020-01-06 -0.767717  0.959169 -0.041342 -0.463239
# 2020-01-03 -0.187262  1.055270  1.896475  0.167401
# 2020-01-02  0.146340  1.476347  0.500801  0.964730

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2020-01-01 -2.143367 -0.770190  1.032366  0.513735
# 2020-01-02  0.146340  1.476347  0.500801  0.964730
# 2020-01-03 -0.187262  1.055270  1.896475  0.167401

# %%
df = pd.DataFrame({
    "Name": ["Braund, Mr. Owen Harris",
             "Allen, Mr. William Henry",
             "Bonnell, Miss. Elizabeth"],
    "Age": [22, 35, 58],
    "Sex": ["male", "male", "female"]})

# %%
df
# Out:
#                        Name  Age     Sex
# 0   Braund, Mr. Owen Harris   22    male
# 1  Allen, Mr. William Henry   35    male
# 2  Bonnell, Miss. Elizabeth   58  female

# %%
df["Age"]
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
ages = pd.Series([22, 35, 58], name='Age')

# %%
ages
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
# read_*
# to_*

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.to_excel('titanic.xlsx', sheet_name='passengers', index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-45-705acd39546e> in <module>
# ----> 1 titanic.to_excel('titanic.xlsx', sheet_name='passengers', index=False)
#
# ~/.local/share/virtualenvs/ironhack-UuIfidyp/lib/python3.7/site-packages/pandas/core/generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2179             startcol=startcol,
#    2180             freeze_panes=freeze_panes,
# -> 2181             engine=engine,
#    2182         )
#    2183
#
# ~/.local/share/virtualenvs/ironhack-UuIfidyp/lib/python3.7/site-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     724             need_save = False
#     725         else:
# --> 726             writer = ExcelWriter(stringify_path(writer), engine=engine)
#     727             need_save = True
#     728
#
# ~/.local/share/virtualenvs/ironhack-UuIfidyp/lib/python3.7/site-packages/pandas/io/excel/_openpyxl.py in __init__(self, path, engine, mode, **engine_kwargs)
#      16     def __init__(self, path, engine=None, mode="w", **engine_kwargs):
#      17         # Use the openpyxl module as the Excel writer.
# ---> 18         from openpyxl.workbook import Workbook
#      19
#      20         super().__init__(path, mode=mode, **engine_kwargs)
#
# ModuleNotFoundError: No module named 'openpyxl'

# %%
titanic[["Age", "Sex"]]
# Out:
#       Age     Sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# ..    ...     ...
# 886  27.0    male
# 887  19.0  female
# 888   NaN  female
# 889  26.0    male
# 890  32.0    male
#
# [891 rows x 2 columns]

# %%
titanic.iloc[0:3]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
above_35 = titanic[titanic["Age"] > 35]

# %%
above_35
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# 865                           Bystrom, Mrs. (Karolina)  female  42.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 873                        Vander Cruyssen, Mr. Victor    male  47.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
#
#      Parch    Ticket     Fare Cabin Embarked
# 1        0  PC 17599  71.2833   C85        C
# 6        0     17463  51.8625   E46        S
# 11       0    113783  26.5500  C103        S
# 13       5    347082  31.2750   NaN        S
# 15       0    248706  16.0000   NaN        S
# ..     ...       ...      ...   ...      ...
# 865      0    236852  13.0000   NaN        S
# 871      1     11751  52.5542   D35        S
# 873      0    345765   9.0000   NaN        S
# 879      1     11767  83.1583   C50        C
# 885      5    382652  29.1250   NaN        Q
#
# [217 rows x 12 columns]

# %%
titanic["Age"] > 35
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
above_35.shape
# Out:
# (217, 12)

# %%
house_dict = {'Baker House': [7420, 'BrkSide', 1939, 5, 118000],
              'Beazley House': [14115, 'Mitchel', 1993, 5, 143000],
              'Dominguez House': [14260, 'NoRidge', 2000, 8, 250000],
              'Hamilton House': [6120, 'OldTown', 1931, 7, 129900],
              'James House': [11250, 'CollgCr', 2001, 7, 223500],
              'Martinez House': [9600, 'Veenker', 1976, 6, 181500],
              'Roberts House': [9550, 'Crawfor', 1915, 7, 140000],
              'Smith House': [8450, 'CollgCr', 2003, 7, 208500],
              'Snyder House': [10084, 'Somerst', 2004, 8, 307000],
              'Zuckerman House': [10382, 'NWAmes', 1973, 7, 200000]}

# %%
df = pd.DataFrame(house_dict)

# %%
colnames = ['LotSize','Neighborhood','YearBuilt','Quality','SalePrice']

# %%
df.transpose()
# Out:
#                      0        1     2  3       4
# Baker House       7420  BrkSide  1939  5  118000
# Beazley House    14115  Mitchel  1993  5  143000
# Dominguez House  14260  NoRidge  2000  8  250000
# Hamilton House    6120  OldTown  1931  7  129900
# James House      11250  CollgCr  2001  7  223500
# Martinez House    9600  Veenker  1976  6  181500
# Roberts House     9550  Crawfor  1915  7  140000
# Smith House       8450  CollgCr  2003  7  208500
# Snyder House     10084  Somerst  2004  8  307000
# Zuckerman House  10382   NWAmes  1973  7  200000

# %%
dft = df.T

# %%
dft.columns= colnames

# %%
dft
# Out:
#                 LotSize Neighborhood YearBuilt Quality SalePrice
# Baker House        7420      BrkSide      1939       5    118000
# Beazley House     14115      Mitchel      1993       5    143000
# Dominguez House   14260      NoRidge      2000       8    250000
# Hamilton House     6120      OldTown      1931       7    129900
# James House       11250      CollgCr      2001       7    223500
# Martinez House     9600      Veenker      1976       6    181500
# Roberts House      9550      Crawfor      1915       7    140000
# Smith House        8450      CollgCr      2003       7    208500
# Snyder House      10084      Somerst      2004       8    307000
# Zuckerman House   10382       NWAmes      1973       7    200000

# %%
df = pd.DataFrame.from_dict(house_dict, orient='index')

# %%
df
# Out:
#                      0        1     2  3       4
# Baker House       7420  BrkSide  1939  5  118000
# Beazley House    14115  Mitchel  1993  5  143000
# Dominguez House  14260  NoRidge  2000  8  250000
# Hamilton House    6120  OldTown  1931  7  129900
# James House      11250  CollgCr  2001  7  223500
# Martinez House    9600  Veenker  1976  6  181500
# Roberts House     9550  Crawfor  1915  7  140000
# Smith House       8450  CollgCr  2003  7  208500
# Snyder House     10084  Somerst  2004  8  307000
# Zuckerman House  10382   NWAmes  1973  7  200000

# %%
df.columns= colnames

# %%
df
# Out:
#                  LotSize Neighborhood  YearBuilt  Quality  SalePrice
# Baker House         7420      BrkSide       1939        5     118000
# Beazley House      14115      Mitchel       1993        5     143000
# Dominguez House    14260      NoRidge       2000        8     250000
# Hamilton House      6120      OldTown       1931        7     129900
# James House        11250      CollgCr       2001        7     223500
# Martinez House      9600      Veenker       1976        6     181500
# Roberts House       9550      Crawfor       1915        7     140000
# Smith House         8450      CollgCr       2003        7     208500
# Snyder House       10084      Somerst       2004        8     307000
# Zuckerman House    10382       NWAmes       1973        7     200000

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic['Fare'].mean()
# Out:
# 32.204207968574636

# %%
titanic['Fare'].max()
# Out:
# 512.3292

# %%
titanic['Fare'].min()
# Out:
# 0.0

# %%
df['LotSize'].sum()
# Out:
# 101231

# %%
#import and export delimited files
#import json files
#read and write to a database

# %%
#csv, delimiteurs autres que ; ou ,

# %%
#json

# %%
#mysql

# %%
data = pd.read_csv('vehicles/vehicles.csv')

# %%
data
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 15 columns]

# %%
data = pd.read_csv('vehicles/vehicles_tab.txt', sep='\t')

# %%
data
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 15 columns]

# %%
data = pd.read_csv('vehicles/vehicles_pipe.txt', sep='|')

# %%
data
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 15 columns]

# %%
#to_*

# %%
data.to_csv('vehicles/vehicles.jm.csv', index=False)

# %%
data.to_csv('vehicles/vehicles.jm.tsv', sep='\t', index=False)

# %%
data.to_csv('vehicles/vehicles.jm.psv', sep='|', index=False)

# %%
data = pd.read_excel('vehicles/vehicles.xlsx')

# %%
#xlrd
#pymysql

# %%
data
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0              4  Automatic 3-spd     2-Wheel Drive
# 1              6  Automatic 3-spd     2-Wheel Drive
# 2              4  Automatic 3-spd  Rear-Wheel Drive
# 3              6  Automatic 3-spd  Rear-Wheel Drive
# 4              6  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947          3        Auto(AM5)  Rear-Wheel Drive
# 35948          3        Auto(AM5)  Rear-Wheel Drive
# 35949          3        Auto(AM5)  Rear-Wheel Drive
# 35950          3        Auto(AM6)  Rear-Wheel Drive
# 35951          3     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 15 columns]

# %%
data.to_excel('vehicles/vehicles.jm.xlsx', index=False)

# %%
{"index": [0, 1, 2], "columns": ['A', 'B'], "values":[[1, 2], [2, 3], [4, 6]]}
# Out:
# {'index': [0, 1, 2], 'columns': ['A', 'B'], 'values': [[1, 2], [2, 3], [4, 6]]}

# %%
[{"A": 2, "B": 3},{"A": 2, "B": 4}]

# %%
data = pd.read_json('vehicles/vehicles.json', orient='records')

# %%
data.head().to_json('vehicles/vehicles.jm.json', orient='records')

# %%
#mysql

# %%
import pymysql

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+pymysql://root:rootpass@localhost/publications')

# %%
data = pd.read_sql_query('SELECT * FROM publications.employee', engine)

# %%
data
# Out:
#        emp_id      fname minit      lname  job_id  job_lvl pub_id  hire_date
# 0   A-C71970F       Aria             Cruz      10       87   1389 1991-10-26
# 1   A-R89858F    Annette           Roulet       6      152   9999 1990-02-21
# 2   AMD15433F        Ann     M      Devon       3      200   9952 1991-07-16
# 3   ARD36773F    Anabela     R  Domingues       8      100   0877 1993-01-27
# 4   CFH28514M     Carlos     F   Hernadez       5      211   9999 1989-04-21
# 5   CGS88322F     Carine     G    Schmitt      13       64   1389 1992-07-07
# 6   DBT39435M     Daniel     B     Tonini      11       75   0877 1990-01-01
# 7   DWR65030M      Diego     W       Roel       6      192   1389 1991-12-16
# 8   ENL44273F  Elizabeth     N    Lincoln      14       35   0877 1990-07-24
# 9   F-C16315M  Francisco            Chang       4      227   9952 1990-11-03
# 10  GHT50241M       Gary     H     Thomas       9      170   0736 1988-08-09
# 11  H-B39728F      Helen          Bennett      12       35   0877 1989-09-21
# 12  HAN90777M  Helvetius     A       Nagy       7      120   9999 1993-03-19
# 13  HAS54740M     Howard     A     Snyder      12      100   0736 1988-11-19
# 14  JYL26161F     Janine     Y    Labrune       5      172   9901 1991-05-26
# 15  KFJ64308F      Karin     F    Josephs      14      100   0736 1992-10-17
# 16  KJJ92907F      Karla     J  Jablonski       9      170   9999 1994-03-11
# 17  L-B31947F     Lesley            Brown       7      120   0877 1991-02-13
# 18  LAL21447M   Laurence     A    Lebihan       5      175   0736 1990-06-03
# 19  M-L67958F      Maria          Larsson       7      135   1389 1992-03-27
# 20  M-P91209M     Manuel          Pereira       8      101   9999 1989-01-09
# 21  M-R38834F    Martine            Rance       9       75   0877 1992-02-05
# 22  MAP77183M     Miguel     A    Paolino      11      112   1389 1992-12-07
# 23  MAS70474F   Margaret     A      Smith       9       78   1389 1988-09-29
# 24  MFS52347M     Martin     F     Sommer      10      165   0736 1990-04-13
# 25  MGK44605M      Matti     G  Karttunen       6      220   0736 1994-05-01
# 26  MJP25939M      Maria     J     Pontes       5      246   1756 1989-03-01
# 27  MMS49649F       Mary     M    Saveley       8      175   0736 1993-06-29
# 28  PCM98509F   Patricia     C    McKenna      11      150   9999 1989-08-01
# 29  PDI47470M      Palle     D      Ibsen       7      195   0736 1993-05-09
# 30  PHF38899M      Peter     H    Franken      10       75   0877 1992-05-17
# 31  PMA42628M      Paolo     M    Accorti      13       35   0877 1992-08-27
# 32  POK93028M     Pirkko     O  Koskitalo      10       80   9999 1993-11-29
# 33  PSA89086M      Pedro     S     Afonso      14       89   1389 1990-12-24
# 34  PSP68661F      Paula     S    Parente       8      125   1389 1994-01-19
# 35  PTC11962M     Philip     T     Cramer       2      215   9952 1989-11-11
# 36  PXH22250M       Paul     X    Henriot       5      159   0877 1993-08-19
# 37  R-M53550M     Roland           Mendel      11      150   0736 1991-09-05
# 38  RBM23061F       Rita     B     Muller       5      198   1622 1993-10-09
# 39  SKO22412M       Sven     K    Ottlieb       5      150   1389 1991-04-05
# 40  TPO55093M    Timothy     P   O'Rourke      13      100   0736 1988-06-19
# 41  VPA30890F   Victoria     P   Ashworth       6      140   0877 1990-09-13
# 42  Y-L77953M      Yoshi          Latimer      12       32   1389 1989-06-11

# %%
data.head().to_sql('employee_jm', engine, if_exists='replace', index=False)

# %%
import mysql.connector as sql
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-35-0a9af4207eaf> in <module>
# ----> 1 import mysql.connector as sql
#
# ModuleNotFoundError: No module named 'mysql'
